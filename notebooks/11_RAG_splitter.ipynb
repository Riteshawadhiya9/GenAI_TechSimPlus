# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
texts = "Technically: RAG is a framework that combines a large language model (LLM) with an external data retrieval system. Instead of relying solely on the \"memory\" (training data) of the AI, RAG allows the AI to search a specific knowledge base (like a company wiki, PDFs, or databases) in real-time, find the relevant information, and use that specific information to generate a factual, accurate answer."

# %%
splitters = RecursiveCharacterTextSplitter( chunk_size = 150 , chunk_overlap = 40 )

# %%
chunks = splitters.split_text(texts)

# %%
chunks
# Out:
# ['Technically: RAG is a framework that combines a large language model (LLM) with an external data retrieval system. Instead of relying solely on the',
#  'Instead of relying solely on the "memory" (training data) of the AI, RAG allows the AI to search a specific knowledge base (like a company wiki,',
#  'knowledge base (like a company wiki, PDFs, or databases) in real-time, find the relevant information, and use that specific information to generate a',
#  'that specific information to generate a factual, accurate answer.']

# %% [markdown]
# # Document Text Loading and Splitting

# %%
from langchain_community.document_loaders import TextLoader , PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
loader = TextLoader('../data/RAG_notes.txt')
text = loader.load()

# %%
pdfLoader = PyPDFLoader("../data/PharmNest_MVP.pdf")
pdfText = pdfLoader.load()
len(pdfText)
# Out:
# 14

# %%
splitters = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=450)

# %%
text_chunks = splitters.split_documents(text)
len(text_chunks)
# Out:
# 21

# %%
text_chunks
# Out:
# [Document(metadata={'source': '../data/RAG_notes.txt'}, page_content='================================================================================\n                    COMPREHENSIVE GUIDE TO RAG\n        (Retrieval-Augmented Generation)\n================================================================================\n                    FOR ABSOLUTE BEGINNERS & EXPERTS\n================================================================================\n\nTABLE OF CONTENTS\n1.  What is RAG? (The Elevator Pitch)\n2.  Why do we need RAG? (The Problem with AI)\n3.  The Core Components (The Pieces of the Puzzle)\n4.  How RAG Works (Step-by-Step Process)\n5.  Visual Block Diagrams (Text-Based Flowcharts)\n6.  Detailed Technical Deep Dive\n7.  Real-World Use Cases (Where is RAG used?)\n8.  Advanced RAG Concepts (The Next Level)\n9.  Summary Cheat Sheet\n\n================================================================================\n1. WHAT IS RAG? (The Elevator Pitch)\n==============
# ...

# %%
pdf_chunks = splitters.split_documents(pdfText)
len(pdf_chunks)
# Out:
# 24

# %%
pdf_chunks
# Out:
# [Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-06-27T22:51:38+00:00', 'author': 'Un-named', 'moddate': '2026-06-27T22:51:38+00:00', 'source': '../data/PharmNest_MVP.pdf', 'total_pages': 14, 'page': 0, 'page_label': '1'}, page_content='PharmNest Technologies \nMVP Feature Specification & Build Blueprint \nVersion 1.0  |  June 2026  |  Confidential \n \nFounder & CEO \nDevansh \nPilot Cities \nJabalpur + Maihar \nTarget Build \n20 Weeks'),
# ...
