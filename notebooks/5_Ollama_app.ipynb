# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="gemma3:1b")
res = llm.invoke("Heyy!! I am Ritesh")
print(res.content)
# Out:
# Hey Ritesh! It's great to meet you. What's up? 😊
#
# How's your day going? Is there anything you'd like to chat about?
