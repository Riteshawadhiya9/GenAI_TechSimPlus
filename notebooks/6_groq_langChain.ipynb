# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="openai/gpt-oss-20b")

# %%
res = llm.invoke("How can I introduce myself in on-campus placement interview? like I am AIML Student and I have a knowledge about front-end development and DSA and in I have solved more than 1700+ DSA problems on across platforms?")
print(res.content)
# Out:
# ## Quick‑Start “Tell‑Me‑About‑Yourself” Script
#
# > **Name, Program, Year**
# > **Key Skills / Strengths**
# > **Concrete Achievements / Projects**
# > **Why You’re a Good Fit**
# > **A Closing Remark / Question**
#
# > **Example (≈30–45 seconds)**
# > “Hi, I’m **[Your Name]**, a senior in **Artificial Intelligence & Machine Learning** at **[University]**. I’ve spent the past three years building a solid foundation in **front‑end development** (React, Vue, CSS‑Grid) and **data structures & algorithms**. On LeetCode, HackerRank, and Codeforces I’ve solved **over 1,700 DSA problems**, consistently ranking in the top 5 % of my cohort. My most recent project, *Smart‑Cart*, is a full‑stack e‑commerce app that uses a recommendation engine I trained on a real‑world dataset. I’m excited about the opportunity to bring my blend of AI insight and user‑centric design to **[Company]** and help build products that are both intelligent and intuitive.”
#
# ---
#
# ## Building Your Own Pitch
#
# ...
