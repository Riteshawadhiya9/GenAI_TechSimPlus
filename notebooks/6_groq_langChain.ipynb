# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="openai/gpt-oss-20b")

# %%
res = llm.invoke("How can I introduce myself in on-campus placement interview? like I am AIML Student and I have a knowledge about front-end development and DSA and in I have solved more than 1700+ DSA problems on across platforms?")
print(res.content)
# Out:
# ### Quick‑Pitch (≈ 60 seconds)
#
# > “Hi, I’m **[Your Name]**, a final‑year **AI & ML** student at **[Your University]**.
# >
# > While my core focus is machine learning, I’ve also built a solid foundation in **front‑end development** (React, HTML5, CSS3, JavaScript) and am comfortable translating data‑driven insights into user‑friendly interfaces.
# >
# > I’ve spent the past 2 years sharpening my algorithmic thinking by solving **over 1,700 DSA problems** on platforms like LeetCode, HackerRank, and Codeforces—often ranking in the top percentile. That practice has taught me to write clean, efficient code and to tackle complex problems under time pressure.
# >
# > I’m excited about the opportunity at **[Company]** because your work on **[specific product or technology]** aligns perfectly with my passion for combining ML models with intuitive user experiences. I’d love to bring my blend of data science, front‑end skills, and problem‑solving mindset to your team.”
#
# ---
#
# ## How to Build and Deliver the Intro
#
# | Step | What to Include | Why It Works |
# |------|-----------------|--------------|
# | **1. Hook** | A one‑sentence elevator pitch (your name, program, and what you bring). | Captures attention immediately. |
# | **2. Academic & Technical Core** | Mention degree, year, and key technical strengths (ML, front‑end, DSA). | Shows relevance to the role. |
# | **3. Quantify Your DSA Experience** | “Solved 1,700+ problems” + platforms + ranking percentile. | Concrete numbers demonstrate depth. |
# | **4. Practical Application** | Briefly reference a project or internship where you used ML + front‑end skills. | Shows you can apply theory to real work. |
# | **5. Fit & Motivation** | Tie your background to the company’s mission/product. | Demonstrates research and genuine interest. |
# | **6. Closing Call‑to‑Action** | “I’d love to contribute….” | Leaves a clear, positive impression. |
#
# ---
#
# ## Sample Scripts (choose the one that best fits your style)
#
# | Context | Script |
# |---------|--------|
# | **Standard** | “Hi, I’m Alex, a senior AI & ML major at Stanford. I’ve built several ML prototypes and also enjoy crafting responsive UIs with React. Over the last two years I’ve solved more than 1,700 DSA problems on LeetCode, HackerRank, and Codeforces, consistently ranking in the top 5 %. I’m excited about the chance to apply my algorithmic and front‑end skills at Google, especially on your AI‑powered product line.” |
# | **If the role is more data‑science focused** | “I’m Maya, an AI & ML student at MIT. My coursework and a recent internship let me develop predictive models, while my passion for clean code led me to solve 1,700+ DSA problems on top platforms—boosting my problem‑solving speed and efficiency. I’m eager to bring that blend of data insight and technical rigor to your analytics team.” |
# | **If the role is front‑end/ML hybrid** | “Hello, I’m Rahul, a final‑year AI & ML major. I’ve built interactive dashboards with React that visualize model outputs, and I’ve spent the past 18 months tackling 1,700+ DSA challenges on LeetCode and HackerRank to sharpen my algorithmic thinking. I’m drawn to your company’s mission to make AI accessible through intuitive interfaces, and I’d love to contribute to that vision.” |
#
# ---
#
# ## Tips for a Polished Delivery
#
# 1. **Practice, but stay natural** – Rehearse until you can speak smoothly, but avoid sounding like a script.
# 2. **Keep it under 60 seconds** – Interviewers appreciate brevity.
# 3. **Use a confident tone** – Speak clearly, maintain eye contact, and smile.
# 4. **Tailor to the company** – Replace placeholders with specific details (product names, values, recent news).
# 5. **Show enthusiasm** – Let your excitement about the role and company shine through.
# 6. **Prepare a quick “story”** – If asked, be ready to elaborate on a DSA problem you solved or a front‑end project you’re proud of.
#
# ---
#
# ### Final Checklist
#
# - [ ] Name, program, and year
# - [ ] Core technical strengths (AI/ML + front‑end)
# - [ ] Quantified DSA achievement
# - [ ] One relevant project or internship
# - [ ] Why you’re interested in this specific company/role
# - [ ] A brief, confident closing
#
# Good luck! With this concise, data‑rich intro, you’ll set a strong tone for the rest of your interview.
