# %%
from dotenv import load_dotenv

load_dotenv()

import pandas as pd

# %%
documents = [
"Machine Learning is a subset of artificial intelligence",
"Deep Learning uses neural networks with multiple layers",
"Python is a programming language popular for data science",
"India won the cricket world cup in 2011",
"AI models can understand and generate human language"
]

# %%
from langchain_mistralai import MistralAIEmbeddings

# %%
embeddings = MistralAIEmbeddings(model="mistral-embed")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
vector = embeddings.embed_documents(documents)
len(vector)
# Out:
# 5

# %%
# len(vector[0]) # 1024
# print(vector)
df = pd.DataFrame(vector) #for this first we have to import pandas as pd
display(df)
# Out:
#        0         1         2         3         4         5         6     \
# 0 -0.012123  0.041351  0.015152  0.017258 -0.012451  0.017258  0.024506
# 1 -0.015915  0.019455  0.012085  0.018982  0.014626  0.020279  0.006870
# 2 -0.019897  0.014183  0.058197 -0.027786  0.001928  0.017258  0.036560
# 3 -0.018723  0.016739  0.047791  0.009514 -0.008408 -0.002424  0.006050
# 4 -0.009254  0.034851  0.013000 -0.004135  0.031708 -0.005581  0.041656
#
#        7         8         9     ...      1014      1015      1016      1017  \
# 0 -0.013374  0.000679 -0.032806  ... -0.019760  0.059540  0.043732  0.016663
# 1 -0.027115 -0.026291 -0.036072  ... -0.042938  0.020279  0.035614  0.025818
# 2  0.002707  0.006142 -0.035675  ... -0.011482  0.004623  0.022369  0.033051
# 3 -0.023132  0.018188 -0.032867  ... -0.023590  0.005020  0.036377  0.038940
# 4 -0.016464  0.012520 -0.034851  ... -0.068298  0.043823  0.010208  0.015854
#
#        1018      1019      1020      1021      1022      1023
# 0  0.014687  0.037415  0.004414 -0.008331  0.007015 -0.005169
# 1 -0.020752  0.029831 -0.003008 -0.001061  0.033722 -0.004925
# 2  0.033203  0.052063  0.012581 -0.028076  0.042694 -0.003529
# 3  0.009888  0.043823 -0.008484 -0.046265  0.037292  0.023438
# 4  0.006840  0.044647  0.011635 -0.009117  0.007896  0.001710
#
# [5 rows x 1024 columns]

# %% [markdown]
# # Store Vector Embeddings in Vector Databases

# %% [markdown]
# ##### use ChromaDB to store vector embeddings and retrieve them using semantic search

# %%
from langchain_chroma import Chroma

# %%
vectorStore = Chroma.from_texts(
    texts=documents,
    embedding=embeddings,
    persist_directory="./vector_db"
)

# %%
query = "covid-19"
result = vectorStore.similarity_search(query=query , k=2) # k means how many similar documents I want to retrieve
result
# Out:
# [Document(id='a1490455-7b0d-42de-900a-c65783e579cd', metadata={}, page_content='Deep Learning uses neural networks with multiple layers'),
#  Document(id='d8d989a4-358e-40c9-ab6b-f5fb6256e793', metadata={}, page_content='Deep Learning uses neural networks with multiple layers')]

# %%
query = "covid-19"
result = vectorStore.similarity_search_with_score(query=query, k=2)  # k means how many similar documents I want to retrieve

for doc, score in result:
    print(f"Score: {score} | Content: {doc.page_content}")
# Out:
# Score: 0.7279219627380371 | Content: Deep Learning uses neural networks with multiple layers
# Score: 0.7279219627380371 | Content: Deep Learning uses neural networks with multiple layers
